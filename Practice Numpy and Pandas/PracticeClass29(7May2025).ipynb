# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('employee.xlsx')

# %% [markdown]
# # Dealing in rows

# %%
data.head(4) # display 5 rows by defaut
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 1       2    1107     Officer         IT  30.0   80000.0
# 2       3    1203     Officer         HR  28.0       NaN
# 3       4    1005     Manager         HR  45.0  120000.0

# %%
data.tail(4)
# Out:
#     Serial  Emp_ID Designation  Department   Age   Salary
# 14      15    2912     Officer          IT  31.0  90000.0
# 15      16    1222     Officer         NaN  25.0      NaN
# 16      17    2156    Engineer  Production  45.0  89000.0
# 17      18    2123  Office Boy    Accounts  27.0  45000.0

# %%
data.sample(4)
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 6       7    1111  Accountant   Accounts   NaN  110000.0
# 5       6    2451  Accountant        NaN  34.0  100000.0
# 3       4    1005     Manager         HR  45.0  120000.0
# 0       1    1101     Manager   Accounts  50.0  200000.0

# %%
data
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
pd.read_excel("employee.xlsx",index_col='Serial')
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 3         1203     Officer          HR  28.0       NaN
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 6         2451  Accountant         NaN  34.0  100000.0
# 7         1111  Accountant    Accounts   NaN  110000.0
# 8         1001     Officer          IT  25.0   75000.0
# 9         1234     Manager          IT  23.0       NaN
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 13        2156    Engineer  Production  45.0   89000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 16        1222     Officer         NaN  25.0       NaN
# ...

# %% [raw]
# data[row,col] >> data[e:s , e:s]

# %%
data[4:11,:] # it does not know it is label or index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(4, 11, None), slice(None, None, None))
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data[4:11,:]
#
# ...

# %%
data.iloc[4:11,:]

# %%
data.iloc[4:11,1:]

# %%
data.iloc[7:10,1:3]

# %%
data.loc[4:11,'Emp_ID':'Age']

# %%
data
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A  115 min
# 996                     Giant          1956           G  201 min
# 997     From Here to Eternity          1953      Passed  118 min
# 998                  Lifeboat          1944         NaN   97 min
# 999              The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# ...

# %%
data.loc[6:12,"Emp_ID":"Age"]

# %%
data.loc[6:12,['Age','Designation','Salary']]

# %%
data.Designation=="Manager"

# %%
data[data.Designation=="Manager"]

# %%
data[data.Age>=50]

# %%
data[data.Salary>100000]

# %%
data[data.Department=='Accounts']['Designation']

# %%
data.Designation[data.Department=='Accounts']

# %%
data.Department[data.Designation=="Manager"]

# %%
data[data.Department=='IT']

# %%
data[(data.Department=='IT') & (data.Designation=='Manager')]

# %%
data[(data.Department=='IT') | (data.Designation=='Manager')]

# %%
data[data.Designation=="Manager"]["Salary"].max()

# %%
data[(data.Designation=="Manager") & (data.Salary==data.Salary.max())]

# %%
data = pd.read_csv("movie.csv")

# %%
data.shape
# Out:
# (1000, 11)

# %%
data.head(10)
# Out:
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# 4                                   12 Angry Men          1957           U
# 5  The Lord of the Rings: The Return of the King          2003           U
# 6                                   Pulp Fiction          1994           A
# 7                               Schindler's List          1993           A
# 8                                      Inception          2010          UA
# 9                                     Fight Club          1999           A
#
#    Runtime                      Genre  IMDB_Rating  Meta_score  \
# 0  142 min                      Drama          9.3        80.0
# ...

# %%
data.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Meta_score       float64
# Director          object
# Star1             object
# No_of_Votes        int64
# Gross            float64
# dtype: object

# %%
data.Released_Year = data.Released_Year.str.replace("PG","1970").astype(int)

# %%
data.Runtime=data.Runtime.str.replace(" min","").astype(int)

# %%
data[data.IMDB_Rating>9]
# Out:
#                Series_Title  Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption           1994           A      142         Drama
# 1             The Godfather           1972           A      175  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  No_of_Votes  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins      2343110
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando      1620367
#
#          Gross
# 0   28341469.0
# 1  134966411.0

# %%
data.Genre.value_counts()
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Adventure, Thriller           1
# Animation, Action, Sci-Fi     1
# Action, Crime, Comedy         1
# Animation, Crime, Mystery     1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %%
data[data.Genre.str.contains("Drama")]
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A      142
# 1               The Godfather           1972           A      175
# 2             The Dark Knight           2008          UA      152
# 3      The Godfather: Part II           1974           A      202
# 4                12 Angry Men           1957           U       96
# ..                        ...            ...         ...      ...
# 993                    Blowup           1966           A      111
# 995    Breakfast at Tiffany's           1961           A      115
# 996                     Giant           1956           G      201
# 997     From Here to Eternity           1953      Passed      118
# 998                  Lifeboat           1944         NaN       97
#
#                         Genre  IMDB_Rating  Meta_score  \
# 0                       Drama          9.3        80.0
# 1                Crime, Drama          9.2       100.0
# ...

# %%
data.sort_values(by='IMDB_Rating', ascending=False)
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A      142
# 1               The Godfather           1972           A      175
# 2             The Dark Knight           2008          UA      152
# 3      The Godfather: Part II           1974           A      202
# 4                12 Angry Men           1957           U       96
# ..                        ...            ...         ...      ...
# 912                Zombieland           2009           A       88
# 911        La piel que habito           2011           R      120
# 910                 Moneyball           2011       PG-13      133
# 909                 Celda 211           2009         NaN      113
# 999              The 39 Steps           1935         NaN       86
#
#                           Genre  IMDB_Rating  Meta_score  \
# 0                         Drama          9.3        80.0
# ...

# %%
max(data.Runtime)
# Out:
# 321

# %%
data[data.Runtime==data.Runtime.max()]
# Out:
#            Series_Title  Released_Year Certificate  Runtime  \
# 140  Gangs of Wasseypur           2012           A      321
#
#                      Genre  IMDB_Rating  Meta_score        Director  \
# 140  Action, Comedy, Crime          8.2        89.0  Anurag Kashyap
#
#               Star1  No_of_Votes  Gross
# 140  Manoj Bajpayee        82365    NaN

# %%
data[data.Star1=="Leonardo DiCaprio"]
# Out:
#                          Series_Title  Released_Year Certificate  Runtime  \
# 8                           Inception           2010          UA      148
# 37                       The Departed           2006           A      151
# 145                    Shutter Island           2010           A      138
# 147           The Wolf of Wall Street           2013           A      180
# 243               Catch Me If You Can           2002           A      141
# 343                      The Revenant           2015           A      156
# 361                     Blood Diamond           2006           A      143
# 652                           Titanic           1997          UA      194
# 879  Once Upon a Time... in Hollywood           2019           A      161
#
#                           Genre  IMDB_Rating  Meta_score  \
# 8     Action, Adventure, Sci-Fi          8.8        74.0
# 37       Crime, Drama, Thriller          8.5        85.0
# ...

# %%
data[data.Gross==data.Gross.max()]
# Out:
#                                    Series_Title  Released_Year Certificate  \
# 477  Star Wars: Episode VII - The Force Awakens           2015           U
#
#      Runtime                      Genre  IMDB_Rating  Meta_score     Director  \
# 477      138  Action, Adventure, Sci-Fi          7.9        80.0  J.J. Abrams
#
#             Star1  No_of_Votes        Gross
# 477  Daisy Ridley       860823  936662225.0

# %%
data[data.Gross>50000000]
# Out:
#                                       Series_Title  Released_Year Certificate  \
# 1                                    The Godfather           1972           A
# 2                                  The Dark Knight           2008          UA
# 3                           The Godfather: Part II           1974           A
# 5    The Lord of the Rings: The Return of the King           2003           U
# 6                                     Pulp Fiction           1994           A
# ..                                             ...            ...         ...
# 979                                  Lethal Weapon           1987           A
# 981                                 On Golden Pond           1981          UA
# 984                               The Muppet Movie           1979           U
# 988             Close Encounters of the Third Kind           1977           U
# 992                                The Jungle Book           1967           U
#
# ...

# %%
data.dtypes
# Out:
# Series_Title      object
# Released_Year      int32
# Certificate       object
# Runtime            int32
# Genre             object
# IMDB_Rating      float64
# Meta_score       float64
# Director          object
# Star1             object
# No_of_Votes        int64
# Gross            float64
# dtype: object
