# %% [markdown]
# # Data Cleanining

# %%
import pandas as pd

# %%
data = pd.read_excel("employee.xlsx")

# %% [markdown]
# # EDA : Exploratory Data Analysis and Data Cleaning

# %% [markdown]
# https://www.geeksforgeeks.org/what-is-exploratory-data-analysis/

# %%
data.shape
# Out:
# (18, 6)

# %%
data.columns
# Out:
# Index(['Serial', 'Emp_ID', 'Designation', 'Department', 'Age', 'Salary'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=18, step=1)

# %%
data.dtypes
# Out:
# Serial           int64
# Emp_ID           int64
# Designation     object
# Department      object
# Age            float64
# Salary         float64
# dtype: object

# %%
data.isna().sum()
# Out:
# Serial         0
# Emp_ID         0
# Designation    0
# Department     2
# Age            1
# Salary         3
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Serial         0
# Emp_ID         0
# Designation    0
# Department     2
# Age            1
# Salary         3
# dtype: int64

# %%
data.notna().sum()
# Out:
# Serial         18
# Emp_ID         18
# Designation    18
# Department     16
# Age            17
# Salary         15
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Serial         18
# Emp_ID         18
# Designation    18
# Department     16
# Age            17
# Salary         15
# dtype: int64

# %% [markdown]
# # Handling Missing Data
#   - Drop
#   - fill

# %% [markdown]
# ##### Fill missing Values
#          - fill with a hardcoded value
#          - mean()
#          - random
#          - mode
#          - median
#          - previous
#          - next

# %%
data.fillna('data missing')  # filled with a hardcoded value
# Out:
#     Serial  Emp_ID Designation    Department           Age        Salary
# 0        1    1101     Manager      Accounts          50.0      200000.0
# 1        2    1107     Officer            IT          30.0       80000.0
# 2        3    1203     Officer            HR          28.0  data missing
# 3        4    1005     Manager            HR          45.0      120000.0
# 4        5    2123  Office Boy      Accounts          27.0       45000.0
# 5        6    2451  Accountant  data missing          34.0      100000.0
# 6        7    1111  Accountant      Accounts  data missing      110000.0
# 7        8    1001     Officer            IT          25.0       75000.0
# 8        9    1234     Manager            IT          23.0  data missing
# 9       10    2156    Engineer    Production          45.0       89000.0
# 10      11    6543     Officer    Production          29.0      100000.0
# 11      12    3214  Accountant       Account          49.0      123000.0
# ...

# %%
data.fillna(0)  # filled with a hardcoded value
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       0.0
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant           0  34.0  100000.0
# 6        7    1111  Accountant    Accounts   0.0  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       0.0
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.Department.fillna(data.Department.mode()[0])
# Out:
# 0       Accounts
# 1             IT
# 2             HR
# 3             HR
# 4       Accounts
# 5             IT
# 6       Accounts
# 7             IT
# 8             IT
# 9     Production
# 10    Production
# 11       Account
# 12    Production
# 13            IT
# 14            IT
# 15            IT
# 16    Production
# 17      Accounts
# Name: Department, dtype: object

# %%
data.Department.mode()[0]
# Out:
# 'IT'

# %%
data.Age
# Out:
# 0     50.0
# 1     30.0
# 2     28.0
# 3     45.0
# 4     27.0
# 5     34.0
# 6      NaN
# 7     25.0
# 8     23.0
# 9     45.0
# 10    29.0
# 11    49.0
# 12    45.0
# 13    25.0
# 14    31.0
# 15    25.0
# 16    45.0
# 17    27.0
# Name: Age, dtype: float64

# %%
data.Age.mean()
# Out:
# 34.294117647058826

# %%
lst = [13,14,15,14,16,15,14,67]

# %%
sum(lst)/len(lst)
# Out:
# 21.0

# %%
import numpy as np
ages = np.array(lst)

# %%
ages.mean()
# Out:
# 21.0

# %%
from statistics import median

# %%
median(ages)
# Out:
# 14.5

# %%
import seaborn as sns

# %%
sns.boxplot(data.Age)
# Out:
# <Axes: ylabel='Age'>

# %% [raw]
# Box Plot : Five Number Summary
#             - min
#             - 25%
#             - median
#             - 75%
#             - max
# https://medium.com/@agarwal.vishal819/outlier-detection-with-boxplots-1b6757fafa21

# %%
data.Age.min()
# Out:
# 23.0

# %%
data.Age.fillna(data.Age.mean())
# Out:
# 0     50.000000
# 1     30.000000
# 2     28.000000
# 3     45.000000
# 4     27.000000
# 5     34.000000
# 6     34.294118
# 7     25.000000
# 8     23.000000
# 9     45.000000
# 10    29.000000
# 11    49.000000
# 12    45.000000
# 13    25.000000
# 14    31.000000
# 15    25.000000
# 16    45.000000
# 17    27.000000
# Name: Age, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(data.Salary)
# Out:
# <Axes: ylabel='Salary'>

# %%
data.Salary.fillna(data.Salary.median())
# Out:
# 0     200000.0
# 1      80000.0
# 2      90000.0
# 3     120000.0
# 4      45000.0
# 5     100000.0
# 6     110000.0
# 7      75000.0
# 8      90000.0
# 9      89000.0
# 10    100000.0
# 11    123000.0
# 12     89000.0
# 13    100000.0
# 14     90000.0
# 15     90000.0
# 16     89000.0
# 17     45000.0
# Name: Salary, dtype: float64

# %%
data.fillna({'Department':data.Department.mode()[0],
             'Age':data.Age.mean(),
              'Salary':data.Salary.median()}, inplace=True)

# %%
data
# Out:
#     Serial  Emp_ID Designation  Department        Age    Salary
# 0        1    1101     Manager    Accounts  50.000000  200000.0
# 1        2    1107     Officer          IT  30.000000   80000.0
# 2        3    1203     Officer          HR  28.000000   90000.0
# 3        4    1005     Manager          HR  45.000000  120000.0
# 4        5    2123  Office Boy    Accounts  27.000000   45000.0
# 5        6    2451  Accountant          IT  34.000000  100000.0
# 6        7    1111  Accountant    Accounts  34.294118  110000.0
# 7        8    1001     Officer          IT  25.000000   75000.0
# 8        9    1234     Manager          IT  23.000000   90000.0
# 9       10    2156    Engineer  Production  45.000000   89000.0
# 10      11    6543     Officer  Production  29.000000  100000.0
# 11      12    3214  Accountant     Account  49.000000  123000.0
# 12      13    2156    Engineer  Production  45.000000   89000.0
# 13      14    1098     Officer          IT  25.000000  100000.0
# ...

# %%
des_f = data.Designation.value_counts()
des_f
# Out:
# Designation
# Officer       7
# Manager       3
# Accountant    3
# Engineer      3
# Office Boy    2
# Name: count, dtype: int64

# %%
plt.bar(x=des_f.index, height=des_f.values)
# Out:
# <BarContainer object of 5 artists>

# %%
data = pd.read_excel('employee.xlsx',index_col='Serial')
data
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 3         1203     Officer          HR  28.0       NaN
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 6         2451  Accountant         NaN  34.0  100000.0
# 7         1111  Accountant    Accounts   NaN  110000.0
# 8         1001     Officer          IT  25.0   75000.0
# 9         1234     Manager          IT  23.0       NaN
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 13        2156    Engineer  Production  45.0   89000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 16        1222     Officer         NaN  25.0       NaN
# ...

# %%
data.dropna(subset=['Emp_ID', 'Department'],how='all')
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 3         1203     Officer          HR  28.0       NaN
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 6         2451  Accountant         NaN  34.0  100000.0
# 7         1111  Accountant    Accounts   NaN  110000.0
# 8         1001     Officer          IT  25.0   75000.0
# 9         1234     Manager          IT  23.0       NaN
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 13        2156    Engineer  Production  45.0   89000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 16        1222     Officer         NaN  25.0       NaN
# ...

# %%
data.dropna(thresh=5,axis=0)
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 8         1001     Officer          IT  25.0   75000.0
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 13        2156    Engineer  Production  45.0   89000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 17        2156    Engineer  Production  45.0   89000.0
# 18        2123  Office Boy    Accounts  27.0   45000.0
# 19        2156    Engineer  Production  45.0   89000.0
# 20        6543     Officer  Production  29.0  100000.0
# 21        3214  Accountant     Account  49.0  123000.0
# ...

# %% [markdown]
# # Dealing with Duplicate Data

# %%
data.duplicated().sum()
# Out:
# 9

# %%
data.drop_duplicates()
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 3         1203     Officer          HR  28.0       NaN
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 6         2451  Accountant         NaN  34.0  100000.0
# 7         1111  Accountant    Accounts   NaN  110000.0
# 8         1001     Officer          IT  25.0   75000.0
# 9         1234     Manager          IT  23.0       NaN
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 16        1222     Officer         NaN  25.0       NaN

# %%
data.duplicated(subset=[])

# %%
data.drop_duplicates()
