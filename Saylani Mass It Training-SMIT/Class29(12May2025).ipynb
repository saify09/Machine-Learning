# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('employee.xlsx')

# %% [markdown]
# # Dealing in Rows

# %%
data.head(4) # display 5 rows by default
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 1       2    1107     Officer         IT  30.0   80000.0
# 2       3    1203     Officer         HR  28.0       NaN
# 3       4    1005     Manager         HR  45.0  120000.0

# %%
data.tail(4)
# Out:
#     Serial  Emp_ID Designation  Department   Age   Salary
# 14      15    2912     Officer          IT  31.0  90000.0
# 15      16    1222     Officer         NaN  25.0      NaN
# 16      17    2156    Engineer  Production  45.0  89000.0
# 17      18    2123  Office Boy    Accounts  27.0  45000.0

# %%
data.sample(4)
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary
# 11      12    3214  Accountant    Account  49.0  123000.0
# 17      18    2123  Office Boy   Accounts  27.0   45000.0
# 14      15    2912     Officer         IT  31.0   90000.0
# 2        3    1203     Officer         HR  28.0       NaN

# %%
data = pd.read_excel("employee.xlsx",index_col='Serial')

# %%
data
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 3         1203     Officer          HR  28.0       NaN
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 6         2451  Accountant         NaN  34.0  100000.0
# 7         1111  Accountant    Accounts   NaN  110000.0
# 8         1001     Officer          IT  25.0   75000.0
# 9         1234     Manager          IT  23.0       NaN
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 13        2156    Engineer  Production  45.0   89000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 16        1222     Officer         NaN  25.0       NaN
# ...

# %% [raw]
# data[row,col] >> data[e:s , e,s]

# %%
data[4:11,:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(4, 11, None), slice(None, None, None))
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data[4:11,:]
#
# ...

# %%
data.iloc[4:10,1:4]
# Out:
#        Designation  Department   Age
# Serial
# 5       Office Boy    Accounts  27.0
# 6       Accountant         NaN  34.0
# 7       Accountant    Accounts   NaN
# 8          Officer          IT  25.0
# 9          Manager          IT  23.0
# 10        Engineer  Production  45.0

# %%
data.iloc[7:10,1:3]
# Out:
#        Designation  Department
# Serial
# 8          Officer          IT
# 9          Manager          IT
# 10        Engineer  Production

# %%
data.loc[10:15, 'Emp_ID':'Age']
# Out:
#         Emp_ID Designation  Department   Age
# Serial
# 10        2156    Engineer  Production  45.0
# 11        6543     Officer  Production  29.0
# 12        3214  Accountant     Account  49.0
# 13        2156    Engineer  Production  45.0
# 14        1098     Officer          IT  25.0
# 15        2912     Officer          IT  31.0

# %%
data = pd.read_excel('employee.xlsx')
data
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.loc[6:12,'Emp_ID':'Age']
# Out:
#     Emp_ID Designation  Department   Age
# 6     1111  Accountant    Accounts   NaN
# 7     1001     Officer          IT  25.0
# 8     1234     Manager          IT  23.0
# 9     2156    Engineer  Production  45.0
# 10    6543     Officer  Production  29.0
# 11    3214  Accountant     Account  49.0
# 12    2156    Engineer  Production  45.0

# %%
data.loc[6:12,['Age','Designation','Salary']]
# Out:
#      Age Designation    Salary
# 6    NaN  Accountant  110000.0
# 7   25.0     Officer   75000.0
# 8   23.0     Manager       NaN
# 9   45.0    Engineer   89000.0
# 10  29.0     Officer  100000.0
# 11  49.0  Accountant  123000.0
# 12  45.0    Engineer   89000.0

# %%
data
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
# select all managers
data[ data.Designation=='Manager' ]
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 3       4    1005     Manager         HR  45.0  120000.0
# 8       9    1234     Manager         IT  23.0       NaN

# %%
# all those who are aged 50 or more
data[data.Age>=50]
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0

# %%
# All those whose salary is more than 100k.
data[data.Salary>100000]
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary
# 0        1    1101     Manager   Accounts  50.0  200000.0
# 3        4    1005     Manager         HR  45.0  120000.0
# 6        7    1111  Accountant   Accounts   NaN  110000.0
# 11      12    3214  Accountant    Account  49.0  123000.0

# %%
# Get the designation of all persons worlking in Accounts Dept.
data[ data.Department=="Accounts"]['Designation']
# Out:
# 0        Manager
# 4     Office Boy
# 6     Accountant
# 17    Office Boy
# Name: Designation, dtype: object

# %%
data.Designation[data.Department=="Accounts"]
# Out:
# 0        Manager
# 4     Office Boy
# 6     Accountant
# 17    Office Boy
# Name: Designation, dtype: object

# %%
# mananger in IT dept
data[(data.Department=='IT') & (data.Designation=='Manager')]
# Out:
#    Serial  Emp_ID Designation Department   Age  Salary
# 8       9    1234     Manager         IT  23.0     NaN

# %%
data[(data.Department=='IT') | (data.Designation=='Manager')]
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary
# 0        1    1101     Manager   Accounts  50.0  200000.0
# 1        2    1107     Officer         IT  30.0   80000.0
# 3        4    1005     Manager         HR  45.0  120000.0
# 7        8    1001     Officer         IT  25.0   75000.0
# 8        9    1234     Manager         IT  23.0       NaN
# 13      14    1098     Officer         IT  25.0  100000.0
# 14      15    2912     Officer         IT  31.0   90000.0

# %%
data[data.Designation=='Manager']
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 3       4    1005     Manager         HR  45.0  120000.0
# 8       9    1234     Manager         IT  23.0       NaN

# %%
data.Salary.max()
# Out:
# 200000.0

# %%
data[(data.Designation=='Manager') & (data.Salary==data.Salary.max())]
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0

# %%
data = pd.read_csv("movie.csv")

# %%
data.shape
# Out:
# (1000, 11)

# %%
data.Runtime
# Out:
# 0      142 min
# 1      175 min
# 2      152 min
# 3      202 min
# 4       96 min
#         ...
# 995    115 min
# 996    201 min
# 997    118 min
# 998     97 min
# 999     86 min
# Name: Runtime, Length: 1000, dtype: object

# %%
data.head(2)
# Out:
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  No_of_Votes  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins      2343110
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando      1620367
#
#          Gross
# 0   28341469.0
# 1  134966411.0

# %%
data.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Meta_score       float64
# Director          object
# Star1             object
# No_of_Votes        int64
# Gross            float64
# dtype: object

# %%
data.Series_Title.unique()
# Out:
# array(['The Shawshank Redemption', 'The Godfather', 'The Dark Knight',
#        'The Godfather: Part II', '12 Angry Men',
#        'The Lord of the Rings: The Return of the King', 'Pulp Fiction',
#        "Schindler's List", 'Inception', 'Fight Club',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'Forrest Gump', 'Il buono, il brutto, il cattivo',
#        'The Lord of the Rings: The Two Towers', 'The Matrix',
#        'Goodfellas', 'Star Wars: Episode V - The Empire Strikes Back',
#        "One Flew Over the Cuckoo's Nest", 'Hamilton', 'Gisaengchung',
#        'Soorarai Pottru', 'Interstellar', 'Cidade de Deus',
#        'Sen to Chihiro no kamikakushi', 'Saving Private Ryan',
#        'The Green Mile', 'La vita è bella', 'Se7en',
#        'The Silence of the Lambs', 'Star Wars', 'Seppuku',
#        'Shichinin no samurai', "It's a Wonderful Life", 'Joker',
#        'Whiplash', 'The Intouchables', 'The Prestige', 'The Departed',
# ...

# %%
data.Released_Year.unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %%
data[data.Released_Year=="PG"]
# Out:
#     Series_Title Released_Year Certificate  Runtime  \
# 966    Apollo 13            PG           U  140 min
#
#                          Genre  IMDB_Rating  Meta_score    Director  \
# 966  Adventure, Drama, History          7.6        77.0  Ron Howard
#
#          Star1  No_of_Votes        Gross
# 966  Tom Hanks       269197  173837933.0

# %%
data.loc[966,'Released_Year'] = 1970

# %%
data.Released_Year = data.Released_Year.astype('int')

# %%
data.Certificate.unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
data.Runtime = data.Runtime.str.replace(" min","").astype(int)

# %%
data.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Meta_score', 'Director', 'Star1', 'No_of_Votes',
#        'Gross'],
#       dtype='object')

# %%
data.Genre.unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History',
#        'Action, Adventure, Sci-Fi', 'Drama, Romance', 'Western',
#        'Action, Sci-Fi', 'Biography, Crime, Drama',
#        'Action, Adventure, Fantasy', 'Comedy, Drama, Thriller',
#        'Adventure, Drama, Sci-Fi', 'Animation, Adventure, Family',
#        'Drama, War', 'Crime, Drama, Fantasy', 'Comedy, Drama, Romance',
#        'Crime, Drama, Mystery', 'Crime, Drama, Thriller',
#        'Action, Drama, Mystery', 'Drama, Family, Fantasy', 'Drama, Music',
#        'Biography, Comedy, Drama', 'Drama, Mystery, Sci-Fi',
#        'Biography, Drama, Music', 'Crime, Mystery, Thriller',
#        'Animation, Adventure, Drama', 'Animation, Drama, War',
#        'Adventure, Comedy, Sci-Fi', 'Horror, Mystery, Thriller',
#        'Drama, Romance, War', 'Comedy, Drama, Family',
#        'Animation, Drama, Fantasy', 'Action, Biography, Drama',
# ...

# %%
data.IMDB_Rating
# Out:
# 0      9.3
# 1      9.2
# 2      9.0
# 3      9.0
# 4      9.0
#       ...
# 995    7.6
# 996    7.6
# 997    7.6
# 998    7.6
# 999    7.6
# Name: IMDB_Rating, Length: 1000, dtype: float64

# %%
data['Meta_score']
# Out:
# 0       80.0
# 1      100.0
# 2       84.0
# 3       90.0
# 4       96.0
#        ...
# 995     76.0
# 996     84.0
# 997     85.0
# 998     78.0
# 999     93.0
# Name: Meta_score, Length: 1000, dtype: float64

# %%
data['Director'].unique()
# Out:
# array(['Frank Darabont', 'Francis Ford Coppola', 'Christopher Nolan',
#        'Sidney Lumet', 'Peter Jackson', 'Quentin Tarantino',
#        'Steven Spielberg', 'David Fincher', 'Robert Zemeckis',
#        'Sergio Leone', 'Lana Wachowski', 'Martin Scorsese',
#        'Irvin Kershner', 'Milos Forman', 'Thomas Kail', 'Bong Joon Ho',
#        'Sudha Kongara', 'Fernando Meirelles', 'Hayao Miyazaki',
#        'Roberto Benigni', 'Jonathan Demme', 'George Lucas',
#        'Masaki Kobayashi', 'Akira Kurosawa', 'Frank Capra',
#        'Todd Phillips', 'Damien Chazelle', 'Olivier Nakache',
#        'Roman Polanski', 'Ridley Scott', 'Tony Kaye', 'Bryan Singer',
#        'Luc Besson', 'Roger Allers', 'James Cameron',
#        'Giuseppe Tornatore', 'Isao Takahata', 'Alfred Hitchcock',
#        'Michael Curtiz', 'Charles Chaplin', 'Nadine Labaki', 'Can Ulkay',
#        'Gayatri', 'Makoto Shinkai', 'Nitesh Tiwari', 'Bob Persichetti',
# ...

# %%
data['No_of_Votes']
# Out:
# 0      2343110
# 1      1620367
# 2      2303232
# 3      1129952
# 4       689845
#         ...
# 995     166544
# 996      34075
# 997      43374
# 998      26471
# 999      51853
# Name: No_of_Votes, Length: 1000, dtype: int64

# %%
data['Gross']
# Out:
# 0       28341469.0
# 1      134966411.0
# 2      534858444.0
# 3       57300000.0
# 4        4360000.0
#           ...
# 995            NaN
# 996            NaN
# 997     30500000.0
# 998            NaN
# 999            NaN
# Name: Gross, Length: 1000, dtype: float64

# %%
data.dtypes
# Out:
# Series_Title      object
# Released_Year      int32
# Certificate       object
# Runtime            int32
# Genre             object
# IMDB_Rating      float64
# Meta_score       float64
# Director          object
# Star1             object
# No_of_Votes        int64
# Gross            float64
# dtype: object

# %%
data.head()
# Out:
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A      142
# 1             The Godfather           1972           A      175
# 2           The Dark Knight           2008          UA      152
# 3    The Godfather: Part II           1974           A      202
# 4              12 Angry Men           1957           U       96
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1  No_of_Votes        Gross
# 0     Tim Robbins      2343110   28341469.0
# 1   Marlon Brando      1620367  134966411.0
# ...

# %% [raw]
# 3. Which movies were released after the year 2000?
#
# 4. Which movies have an IMDB rating greater than 9?
#
# 5. How many movies are there for each genre?
#
# 6. Which movies were directed by Christopher Nolan?
#
# 7. Which movies have "Drama" mentioned in their genre?
#
# 8. How can we sort all movies by IMDB rating in descending order?
#
# 9. How can we sort all movies by the number of votes they received?
#
# 10. Which movie has the longest runtime?
#
# 11. Which movies have Leonardo DiCaprio listed as the first star (Star1)?
#
# 12. What is the average IMDB rating of all movies?
#
# 13. How many movies were released each year?
#
# 14. Who are the top 5 directors with the most movies in the dataset?
#
# 15. Which movies earned more than $500 million in gross revenue?
#
# 16. In which movies did Morgan Freeman act (as Star1, Star2, Star3, or Star4)?
#
# 17. What is the total number of votes across all movies?
#
# 18. Which movies have titles that start with the word "The"?
#
# 19. Which movies were released between 1990 and 2000?
#
# 20. Which movies have a Meta score greater than 90?

# %%
data.Released_Year.value_counts()
# Out:
# Released_Year
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1930     1
# 1921     1
# 1936     1
# 1922     1
# 1943     1
# Name: count, Length: 99, dtype: int64

# %%
data[data.Released_Year>2000]
# Out:
#                                           Series_Title  Released_Year  \
# 2                                      The Dark Knight           2008
# 5        The Lord of the Rings: The Return of the King           2003
# 8                                            Inception           2010
# 10   The Lord of the Rings: The Fellowship of the Ring           2001
# 13               The Lord of the Rings: The Two Towers           2002
# ..                                                 ...            ...
# 947              Harry Potter and the Sorcerer's Stone           2001
# 948                                         The Others           2001
# 949                                               Blow           2001
# 950                                 Enemy at the Gates           2001
# 951                                    Minority Report           2002
#
#     Certificate  Runtime                       Genre  IMDB_Rating  Meta_score  \
# ...

# %%
data[data.IMDB_Rating>9]
# Out:
#                Series_Title  Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption           1994           A      142         Drama
# 1             The Godfather           1972           A      175  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  No_of_Votes  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins      2343110
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando      1620367
#
#          Gross
# 0   28341469.0
# 1  134966411.0

# %%
data.Genre.value_counts()
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Adventure, Thriller           1
# Animation, Action, Sci-Fi     1
# Action, Crime, Comedy         1
# Animation, Crime, Mystery     1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %% [markdown]
# # Which movies have "Drama" mentioned in their genre?

# %%
data[data.Genre.str.contains('Drama')]
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A      142
# 1               The Godfather           1972           A      175
# 2             The Dark Knight           2008          UA      152
# 3      The Godfather: Part II           1974           A      202
# 4                12 Angry Men           1957           U       96
# ..                        ...            ...         ...      ...
# 993                    Blowup           1966           A      111
# 995    Breakfast at Tiffany's           1961           A      115
# 996                     Giant           1956           G      201
# 997     From Here to Eternity           1953      Passed      118
# 998                  Lifeboat           1944         NaN       97
#
#                         Genre  IMDB_Rating  Meta_score  \
# 0                       Drama          9.3        80.0
# 1                Crime, Drama          9.2       100.0
# ...

# %%
 # How can we sort all movies by IMDB rating in descending order?

# %%
data.sort_values(by='IMDB_Rating', ascending=False)
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A      142
# 1               The Godfather           1972           A      175
# 2             The Dark Knight           2008          UA      152
# 3      The Godfather: Part II           1974           A      202
# 4                12 Angry Men           1957           U       96
# ..                        ...            ...         ...      ...
# 912                Zombieland           2009           A       88
# 911        La piel que habito           2011           R      120
# 910                 Moneyball           2011       PG-13      133
# 909                 Celda 211           2009         NaN      113
# 999              The 39 Steps           1935         NaN       86
#
#                           Genre  IMDB_Rating  Meta_score  \
# 0                         Drama          9.3        80.0
# ...

# %%
data[data.Runtime == data.Runtime.max()]
# Out:
#            Series_Title  Released_Year Certificate  Runtime  \
# 140  Gangs of Wasseypur           2012           A      321
#
#                      Genre  IMDB_Rating  Meta_score        Director  \
# 140  Action, Comedy, Crime          8.2        89.0  Anurag Kashyap
#
#               Star1  No_of_Votes  Gross
# 140  Manoj Bajpayee        82365    NaN

# %%
# Out:
# 321
